# %% [markdown]
# ### This is for debugging the code

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
from sys import path
path.append('..')

# %%
from solar_data_pipeline.database.cassandra import CassandraDataAccess

# %%
data_access = CassandraDataAccess("127.0.0.1")

# %%
sites = data_access.get_sites()
sites
# Out:
# array(['SLACA0000001', 'SLACA0000002'], dtype='<U12')

# %%
site_1_data = data_access.retrieve(sites=['SLACA0000001'])
site_1_data
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
# ...

# %%
plt.imshow(site_1_data)

# %%
plt.plot(site_1_data[:,0])

# %%
plt.plot(site_1_data[:,1])

# %%
plt.plot(site_1_data[:,2])

# %%
plt.plot(site_1_data[:,3])

# %%
plt.plot(site_1_data[:,4])

# %%
plt.plot(site_1_data[:,5])

# %%
site_1_data.shape
# Out:
# (288, 6)

# %%
input_power_signals_file_path = "../tests/fixtures/one_year_power_signals_1.csv"
with open(input_power_signals_file_path) as file:
    one_year_power_signals = np.loadtxt(file, delimiter=',')
power_signals_site_1 = one_year_power_signals[:, :6]

# %%
power_signals_site_1.shape
# Out:
# (288, 6)

# %%
plt.imshow(power_signals_site_1)

# %%
plt.plot(power_signals_site_1[:,0])

# %%
plt.plot(power_signals_site_1[:,1])

# %%
plt.plot(power_signals_site_1[:,2])

# %%
plt.plot(power_signals_site_1[:,3])

# %%
plt.plot(power_signals_site_1[:,4])

# %%
plt.plot(power_signals_site_1[:,5])

# %%
(site_1_data[:,0] == power_signals_site_1[:,0]).all()
# Out:
# False

# %%
site_1_data[:,0][100] == power_signals_site_1[:,0][100]
# Out:
# False

# %%
site_1_data[:,0][100]
# Out:
# 27.945411682128906

# %%
power_signals_site_1[:,0][100]
# Out:
# 27.94541227918252
